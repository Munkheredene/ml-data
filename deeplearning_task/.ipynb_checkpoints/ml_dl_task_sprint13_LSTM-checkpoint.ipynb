# %% [markdown]
# Problem 1 Execution of various methods
# Keras provides 4 types of Reccurent layers. All but SimpleRNN are gated recurrent neural networks.

# %%
from __future__ import print_function
from keras.preprocessing import sequence
from keras.models import Sequential
from keras.layers import Dense, Embedding,SimpleRNN,LSTM
from keras.layers import LSTM
from keras.datasets import imdb
from keras import backend as K

# %%
from keras.layers.convolutional import Conv3D
from keras.layers import LSTM  
from keras.layers import BatchNormalization
import numpy as np
import pylab as plt
from keras.utils.data_utils import pad_sequences
from tensorflow.keras.preprocessing.sequence import pad_sequences

# %%
max_features = 20000
# cut texts after this number of words (among top max_features most common words)
maxlen = 80
batch_size = 32

print('Loading data...')
(x_train, y_train), (x_test, y_test) = imdb.load_data(num_words=max_features)
print(len(x_train), 'train sequences')
print(len(x_test), 'test sequences')

print('Pad sequences (samples x time)')
x_train = pad_sequences(x_train, maxlen=maxlen)
x_test = pad_sequences(x_test, maxlen=maxlen)
print('x_train shape:', x_train.shape)
print('x_test shape:', x_test.shape)
# Out:
# Loading data...
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/imdb.npz
# 17464789/17464789 [==============================] - 3s 0us/step
# 25000 train sequences
# 25000 test sequences
# Pad sequences (samples x time)
# x_train shape: (25000, 80)
# x_test shape: (25000, 80)

# %% [markdown]
# Problem 1 Execution of various methods

# %%
print('Build model...')
model = Sequential()

model.add(Embedding(max_features, 128))
model.add(LSTM(128, dropout=0.2, recurrent_dropout=0.2))
model.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
model.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
model.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))
score, acc = model.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Test score:', score)
print('Test accuracy:', acc)
# Out:
# Build model...
# Train...
# Epoch 1/15
# 782/782 [==============================] - 215s 271ms/step - loss: 0.4315 - accuracy: 0.7964 - val_loss: 0.4010 - val_accuracy: 0.8173
# Epoch 2/15
# 782/782 [==============================] - 222s 284ms/step - loss: 0.2541 - accuracy: 0.8993 - val_loss: 0.3819 - val_accuracy: 0.8399
# Epoch 3/15
# 782/782 [==============================] - 220s 282ms/step - loss: 0.1636 - accuracy: 0.9394 - val_loss: 0.4623 - val_accuracy: 0.8217
# Epoch 4/15
# 782/782 [==============================] - 220s 282ms/step - loss: 0.1090 - accuracy: 0.9597 - val_loss: 0.5139 - val_accuracy: 0.8260
# Epoch 5/15
# 782/782 [==============================] - 222s 284ms/step - loss: 0.0741 - accuracy: 0.9752 - val_loss: 0.6788 - val_accuracy: 0.8192
# Epoch 6/15
# 782/782 [==============================] - 225s 288ms/step - loss: 0.0550 - accuracy: 0.9814 - val_loss: 0.6808 - val_accuracy: 0.8148
# Epoch 7/15
# 782/782 [==============================] - 224s 286ms/step - loss: 0.0381 - accuracy: 0.9882 - val_loss: 0.8647 - val_accuracy: 0.8102
# Epoch 8/15
# 782/782 [==============================] - 223s 286ms/step - loss: 0.0298 - accuracy: 0.9904 - val_loss: 0.9022 - val_accuracy: 0.8202
# Epoch 9/15
# 782/782 [==============================] - 225s 288ms/step - loss: 0.0203 - accuracy: 0.9937 - val_loss: 0.8152 - val_accuracy: 0.8213
# Epoch 10/15
# 782/782 [==============================] - 223s 286ms/step - loss: 0.0277 - accuracy: 0.9909 - val_loss: 1.0915 - val_accuracy: 0.7949
# Epoch 11/15
# 782/782 [==============================] - 224s 287ms/step - loss: 0.0244 - accuracy: 0.9918 - val_loss: 0.9253 - val_accuracy: 0.8164
# Epoch 12/15
# 782/782 [==============================] - 225s 288ms/step - loss: 0.0136 - accuracy: 0.9960 - val_loss: 0.9779 - val_accuracy: 0.8158
# Epoch 13/15
# 782/782 [==============================] - 225s 288ms/step - loss: 0.0129 - accuracy: 0.9961 - val_loss: 0.9506 - val_accuracy: 0.8178
# Epoch 14/15
# 782/782 [==============================] - 226s 289ms/step - loss: 0.0079 - accuracy: 0.9978 - val_loss: 1.0956 - val_accuracy: 0.8130
# Epoch 15/15
# 782/782 [==============================] - 225s 288ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 1.1507 - val_accuracy: 0.8118
# 782/782 [==============================] - 32s 41ms/step - loss: 1.1507 - accuracy: 0.8118
# Test score: 1.1507432460784912
# Test accuracy: 0.8117600083351135

# %%
from keras.layers import SimpleRNN

# %%
print('Build model Simple RNN')
simplernnmodel = Sequential()

simplernnmodel.add(Embedding(max_features, 128))
simplernnmodel.add(SimpleRNN(128, dropout=0.2, recurrent_dropout=0.2))
simplernnmodel.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
simplernnmodel.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
simplernnmodel.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))
score, acc = simplernnmodel.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('Simple RNN Test score:', score)
print('Simpke RNN Test accuracy:', acc)
# Out:
# Build model Simple RNN
# Train...
# Epoch 1/15
# 782/782 [==============================] - 75s 94ms/step - loss: 0.6966 - accuracy: 0.5224 - val_loss: 0.6861 - val_accuracy: 0.5419
# Epoch 2/15
# 782/782 [==============================] - 77s 99ms/step - loss: 0.6408 - accuracy: 0.6197 - val_loss: 0.5216 - val_accuracy: 0.7414
# Epoch 3/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.5172 - accuracy: 0.7508 - val_loss: 0.5451 - val_accuracy: 0.7323
# Epoch 4/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.5071 - accuracy: 0.7562 - val_loss: 0.6481 - val_accuracy: 0.6047
# Epoch 5/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.5114 - accuracy: 0.7509 - val_loss: 0.5596 - val_accuracy: 0.7240
# Epoch 6/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.4107 - accuracy: 0.8161 - val_loss: 0.4889 - val_accuracy: 0.7816
# Epoch 7/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.4780 - accuracy: 0.7776 - val_loss: 0.6084 - val_accuracy: 0.7086
# Epoch 8/15
# 782/782 [==============================] - 72s 92ms/step - loss: 0.4023 - accuracy: 0.8253 - val_loss: 0.6740 - val_accuracy: 0.7138
# Epoch 9/15
# 782/782 [==============================] - 72s 92ms/step - loss: 0.3724 - accuracy: 0.8417 - val_loss: 0.6230 - val_accuracy: 0.7202
# Epoch 10/15
# 782/782 [==============================] - 72s 92ms/step - loss: 0.3999 - accuracy: 0.8161 - val_loss: 0.5450 - val_accuracy: 0.7693
# Epoch 11/15
# 782/782 [==============================] - 72s 92ms/step - loss: 0.3309 - accuracy: 0.8630 - val_loss: 0.6158 - val_accuracy: 0.7064
# Epoch 12/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.3077 - accuracy: 0.8712 - val_loss: 0.6019 - val_accuracy: 0.7538
# Epoch 13/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.3169 - accuracy: 0.8694 - val_loss: 0.6389 - val_accuracy: 0.6667
# Epoch 14/15
# 782/782 [==============================] - 73s 94ms/step - loss: 0.3449 - accuracy: 0.8523 - val_loss: 0.6546 - val_accuracy: 0.7364
# Epoch 15/15
# 782/782 [==============================] - 73s 93ms/step - loss: 0.4160 - accuracy: 0.8042 - val_loss: 0.6385 - val_accuracy: 0.6732
# 782/782 [==============================] - 12s 15ms/step - loss: 0.6385 - accuracy: 0.6732
# Simple RNN Test score: 0.6385298371315002
# Simpke RNN Test accuracy: 0.6731600165367126

# %%
from keras.layers import GRU

# %%
print('Build model GRU')
grumodel = Sequential()

grumodel.add(Embedding(max_features, 128))
grumodel.add(GRU(128, dropout=0.2, recurrent_dropout=0.2))
grumodel.add(Dense(1, activation='sigmoid'))

# try using different optimizers and different optimizer configs
grumodel.compile(loss='binary_crossentropy',
              optimizer='adam',
              metrics=['accuracy'])

print('Train...')
grumodel.fit(x_train, y_train,
          batch_size=batch_size,
          epochs=15,
          validation_data=(x_test, y_test))
score, acc = grumodel.evaluate(x_test, y_test,
                            batch_size=batch_size)
print('GRU Test score:', score)
print('GRU Test accuracy:', acc)
# Out:
# Build model GRU
# Train...
# Epoch 1/15
# 782/782 [==============================] - 174s 219ms/step - loss: 0.4358 - accuracy: 0.7886 - val_loss: 0.3459 - val_accuracy: 0.8477
# Epoch 2/15
# 782/782 [==============================] - 171s 219ms/step - loss: 0.2397 - accuracy: 0.9050 - val_loss: 0.3492 - val_accuracy: 0.8457
# Epoch 3/15
# 782/782 [==============================] - 171s 219ms/step - loss: 0.1390 - accuracy: 0.9490 - val_loss: 0.4527 - val_accuracy: 0.8364
# Epoch 4/15
# 782/782 [==============================] - 169s 216ms/step - loss: 0.0738 - accuracy: 0.9747 - val_loss: 0.6532 - val_accuracy: 0.8212
# Epoch 5/15
# 782/782 [==============================] - 169s 217ms/step - loss: 0.0409 - accuracy: 0.9865 - val_loss: 0.7137 - val_accuracy: 0.8208
# Epoch 6/15
# 782/782 [==============================] - 170s 217ms/step - loss: 0.0277 - accuracy: 0.9904 - val_loss: 0.8121 - val_accuracy: 0.8201
# Epoch 7/15
# 782/782 [==============================] - 168s 215ms/step - loss: 0.0191 - accuracy: 0.9939 - val_loss: 0.8127 - val_accuracy: 0.8218
# Epoch 8/15
# 782/782 [==============================] - 169s 217ms/step - loss: 0.0122 - accuracy: 0.9960 - val_loss: 1.0220 - val_accuracy: 0.8177
# Epoch 9/15
# 782/782 [==============================] - 168s 215ms/step - loss: 0.0117 - accuracy: 0.9959 - val_loss: 0.9636 - val_accuracy: 0.8150
# Epoch 10/15
# 782/782 [==============================] - 167s 214ms/step - loss: 0.0124 - accuracy: 0.9963 - val_loss: 0.9935 - val_accuracy: 0.8178
# Epoch 11/15
# 782/782 [==============================] - 168s 215ms/step - loss: 0.0063 - accuracy: 0.9978 - val_loss: 1.0716 - val_accuracy: 0.8146
# Epoch 12/15
# 782/782 [==============================] - 170s 217ms/step - loss: 0.0043 - accuracy: 0.9985 - val_loss: 1.2389 - val_accuracy: 0.8172
# Epoch 13/15
# 782/782 [==============================] - 168s 215ms/step - loss: 0.0083 - accuracy: 0.9972 - val_loss: 1.1625 - val_accuracy: 0.8178
# Epoch 14/15
# 782/782 [==============================] - 169s 216ms/step - loss: 0.0055 - accuracy: 0.9982 - val_loss: 1.3242 - val_accuracy: 0.8106
# Epoch 15/15
# 782/782 [==============================] - 168s 215ms/step - loss: 0.0051 - accuracy: 0.9982 - val_loss: 1.3502 - val_accuracy: 0.8119
# 782/782 [==============================] - 29s 38ms/step - loss: 1.3502 - accuracy: 0.8119
# GRU Test score: 1.3501962423324585
# GRU Test accuracy: 0.8119199872016907

# %% [markdown]
# Test score: 1.1507432460784912
# Test accuracy: 0.8117600083351135
#
# SimpleRNN:
# Simple RNN Test score: 0.6385298371315002
# Simpke RNN Test accuracy: 0.6731600165367126
#
# GRU Test score: 1.3501962423324585
# GRU Test accuracy: 0.8119199872016907

# %%
def generate_movies(n_samples=1200, n_frames=15):
    row = 80
    col = 80
    noisy_movies = np.zeros((n_samples, n_frames, row, col, 1), dtype=np.float32)
    shifted_movies = np.zeros((n_samples, n_frames, row, col, 1),dtype=np.float32)
    for i in range(n_samples):
        n = np.random.randint(3, 8)
        for j in range(n):
            xstart = np.random.randint(20, 60)
            ystart = np.random.randint(20, 60)
            directionx = np.random.randint(0, 3) - 1
            directiony = np.random.randint(0, 3) - 1
            w = np.random.randint(2, 4)
            for t in range(n_frames):
                x_shift = xstart + directionx * t
                y_shift = ystart + directiony * t
                noisy_movies[i, t, x_shift - w: x_shift + w,y_shift - w: y_shift + w, 0] += 1
                if np.random.randint(0, 2):
                    noise_f = (-1)**np.random.randint(0, 2)
                    noisy_movies[i, t,x_shift - w - 1: x_shift + w + 1,y_shift - w - 1: y_shift + w + 1,0] += noise_f * 0.1
                x_shift = xstart + directionx * (t + 1)
                y_shift = ystart + directiony * (t + 1)
                shifted_movies[i, t, x_shift - w: x_shift + w,y_shift - w: y_shift + w, 0] += 1
    noisy_movies = noisy_movies[::, ::, 20:60, 20:60, ::]
    shifted_movies = shifted_movies[::, ::, 20:60, 20:60, ::]
    noisy_movies[noisy_movies >= 1] = 1
    shifted_movies[shifted_movies >= 1] = 1
    return noisy_movies, shifted_movies

noisy_movies, shifted_movies = generate_movies(n_samples=1200)

# %%
index = 1
x = noisy_movies[index]
fig = plt.figure()
viewer = fig.add_subplot(111)
plt.ion()
fig.show()
for i in range(len(x)):
    viewer.clear()
    viewer.imshow(x[i])
    plt.pause(.1)
    fig.canvas.draw()
# Out:
# C:\Users\munkherdene\AppData\Local\Temp\ipykernel_28524\543104287.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()

# %%
from tensorflow.python.keras.layers import ConvLSTM2D
     

seq = Sequential()
seq.add(ConvLSTM2D(filters=40, kernel_size=(3, 3),input_shape=(None, 40, 40, 1),padding='same', return_sequences=True))
seq.add(BatchNormalization())
seq.add(ConvLSTM2D(filters=40, kernel_size=(3, 3),padding='same', return_sequences=True))
seq.add(BatchNormalization())
seq.add(ConvLSTM2D(filters=40, kernel_size=(3, 3),padding='same', return_sequences=True))
seq.add(BatchNormalization())
seq.add(ConvLSTM2D(filters=40, kernel_size=(3, 3),padding='same', return_sequences=True))
seq.add(BatchNormalization())
seq.add(Conv3D(filters=1, kernel_size=(3, 3, 3),activation='sigmoid',padding='same', data_format='channels_last'))
seq.compile(loss='binary_crossentropy', optimizer='adadelta')
     

seq.fit(noisy_movies[:100], shifted_movies[:100], batch_size=10,epochs=1, validation_split=0.05)
# Out:
# 10/10 [==============================] - 216s 20s/step - loss: 0.9044 - val_loss: 0.6925

# %%
index = 1004
track = noisy_movies[index][:7, ::, ::, ::] 
track2 = noisy_movies[index][::, ::, ::, ::]
for j in range(16):
    new_pos = seq.predict(track[np.newaxis, ::, ::, ::, ::])
    new = new_pos[::, -1, ::, ::, ::]
    track = np.concatenate((track, new), axis=0)
for i in range(15):
    fig = plt.figure(figsize=(10, 5))
    ax = fig.add_subplot(121)
    if i >= 7:
        ax.text(1, 3, 'Predictions !', fontsize=20, color='w')
    else:
        ax.text(1, 3, 'Initial trajectory', fontsize=20)
    toplot = track[i, ::, ::, 0]
    plt.imshow(toplot)
    ax = fig.add_subplot(122)
    plt.text(1, 3, 'Ground truth', fontsize=20)
    toplot = track2[i, ::, ::, 0]
    if i >= 2:
        toplot = shifted_movies[index][i - 1, ::, ::, 0]
    plt.imshow(toplot)
    plt.savefig('%i_animate.png' % (i + 1))
# Out:
# 1/1 [==============================] - 2s 2s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 527ms/step
# 1/1 [==============================] - 1s 572ms/step
# 1/1 [==============================] - 1s 602ms/step
# 1/1 [==============================] - 1s 673ms/step
# 1/1 [==============================] - 1s 719ms/step
# 1/1 [==============================] - 1s 796ms/step
# 1/1 [==============================] - 1s 866ms/step
# 1/1 [==============================] - 1s 893ms/step
# 1/1 [==============================] - 1s 911ms/step
# 1/1 [==============================] - 1s 989ms/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step
# 1/1 [==============================] - 1s 1s/step

# %% [markdown]
# Question 3 Description of other classes
#
# There are other related classes mentioned in the documentation. Please explain what they are. This includes classes that are rarely dealt with.
#
# RNN SimpleRNNCell GRUCell LSTMCell StackedRNNCells CoDNNGRU CuDNNLSTM
#
# Answer: RNN - RNN cells distinguish themselves from the regular neurons in the sense that they have a state and thus can remember information from the past.
#
# SimpleRNNCell - SimpleRNN Cell class- A Recurrent neural network can be seen as the repetition of a single cell.
#
# LSTMCell - Cell class of LSTM layer - LSTM is a one kind of RNN and capable of learning long-term dependencies. LSTM cell consists of three gates including the forget gate, the input gate and the output gate.
#
# GRUCell - Cell class of GRU layer - It is similar to LSTM. However it does not have a cell state (Ct). It only has a hidden state(Ht). Due to the simpler architecture, GRUs are faster to train.
#
# StackedRNNCells - A wrapper that makes the behavior of an RNN cell stack look like a single cell. It is used to implement an efficient stacked RNN.
#
# CoDNNGRU - Fast GRU implementation backed by cuDNN. - Can only be run on GPU.
#
# CuDNNLSTM - Fast LSTM implementation backed by cuDNN - Can only be run on GPU.
