# %%
from model import *
from data import *

# %% [markdown]
# ## Train your Unet with membrane data
# membrane data is in folder membrane/, it is a binary classification task.
#
# The input shape of image and mask are the same :(batch_size,rows,cols,channel = 1)

# %% [markdown]
# ### Train with data generator

# %%
data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'data/membrane/train','image','label',data_gen_args,save_to_dir = None)

# %%
model = unet()
model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=2000,epochs=5,callbacks=[model_checkpoint])
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 128, 128, 16  448         ['input_1[0][0]']
#                                 )
#
#  dropout (Dropout)              (None, 128, 128, 16  0           ['conv2d[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 128, 128, 16  2320        ['dropout[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 128, 128, 16  64         ['conv2d_1[0][0]']
#  alization)                     )
#
#  re_lu (ReLU)                   (None, 128, 128, 16  0           ['batch_normalization[0][0]']
#                                 )
#
#  max_pooling2d (MaxPooling2D)   (None, 64, 64, 16)   0           ['re_lu[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 64, 64, 32)   4640        ['max_pooling2d[0][0]']
#
#  dropout_1 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_2[0][0]']
#
#  conv2d_3 (Conv2D)              (None, 64, 64, 32)   9248        ['dropout_1[0][0]']
#
#  batch_normalization_1 (BatchNo  (None, 64, 64, 32)  128         ['conv2d_3[0][0]']
#  rmalization)
#
#  re_lu_1 (ReLU)                 (None, 64, 64, 32)   0           ['batch_normalization_1[0][0]']
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 32, 32, 32)  0           ['re_lu_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 32, 32, 64)   18496       ['max_pooling2d_1[0][0]']
#
#  dropout_2 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_4[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 32, 32, 64)   36928       ['dropout_2[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 32, 32, 64)  256         ['conv2d_5[0][0]']
#  rmalization)
#
#  re_lu_2 (ReLU)                 (None, 32, 32, 64)   0           ['batch_normalization_2[0][0]']
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 16, 16, 64)  0           ['re_lu_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 16, 16, 128)  73856       ['max_pooling2d_2[0][0]']
#
#  dropout_3 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_6[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 16, 16, 128)  147584      ['dropout_3[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 16, 16, 128)  512        ['conv2d_7[0][0]']
#  rmalization)
#
#  re_lu_3 (ReLU)                 (None, 16, 16, 128)  0           ['batch_normalization_3[0][0]']
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 8, 8, 128)   0           ['re_lu_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 8, 8, 256)    295168      ['max_pooling2d_3[0][0]']
#
#  batch_normalization_4 (BatchNo  (None, 8, 8, 256)   1024        ['conv2d_8[0][0]']
#  rmalization)
#
#  re_lu_4 (ReLU)                 (None, 8, 8, 256)    0           ['batch_normalization_4[0][0]']
#
#  dropout_4 (Dropout)            (None, 8, 8, 256)    0           ['re_lu_4[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 8, 8, 256)    590080      ['dropout_4[0][0]']
#
#  conv2d_transpose (Conv2DTransp  (None, 16, 16, 128)  131200     ['conv2d_9[0][0]']
#  ose)
#
#  concatenate (Concatenate)      (None, 16, 16, 256)  0           ['conv2d_transpose[0][0]',
#                                                                   'conv2d_7[0][0]']
#
#  batch_normalization_5 (BatchNo  (None, 16, 16, 256)  1024       ['concatenate[0][0]']
#  rmalization)
#
#  re_lu_5 (ReLU)                 (None, 16, 16, 256)  0           ['batch_normalization_5[0][0]']
#
#  conv2d_transpose_1 (Conv2DTran  (None, 32, 32, 64)  65600       ['re_lu_5[0][0]']
#  spose)
#
#  concatenate_1 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_1[0][0]',
#                                                                   'conv2d_5[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 32, 32, 128)  512        ['concatenate_1[0][0]']
#  rmalization)
#
#  re_lu_6 (ReLU)                 (None, 32, 32, 128)  0           ['batch_normalization_6[0][0]']
#
#  conv2d_transpose_2 (Conv2DTran  (None, 64, 64, 32)  16416       ['re_lu_6[0][0]']
#  spose)
#
#  concatenate_2 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_2[0][0]',
#                                                                   'conv2d_3[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 64)  256         ['concatenate_2[0][0]']
#  rmalization)
#
#  re_lu_7 (ReLU)                 (None, 64, 64, 64)   0           ['batch_normalization_7[0][0]']
#
#  conv2d_transpose_3 (Conv2DTran  (None, 128, 128, 16  4112       ['re_lu_7[0][0]']
#  spose)                         )
#
#  concatenate_3 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_3[0][0]',
#                                 )                                 'conv2d_1[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 128, 128, 32  128        ['concatenate_3[0][0]']
#  rmalization)                   )
#
#  re_lu_8 (ReLU)                 (None, 128, 128, 32  0           ['batch_normalization_8[0][0]']
#                                 )
#
#  conv2d_10 (Conv2D)             (None, 128, 128, 1)  33          ['re_lu_8[0][0]']
#
# ==================================================================================================
# Total params: 1,400,033
# Trainable params: 1,398,081
# Non-trainable params: 1,952
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 model = unet()
# ----> 2 model_checkpoint = ModelCheckpoint('unet_membrane.hdf5', monitor='loss',verbose=1, save_best_only=True)
#       3 model.fit_generator(myGene,steps_per_epoch=2000,epochs=5,callbacks=[model_checkpoint])
#
# NameError: name 'ModelCheckpoint' is not defined

# %% [markdown]
# ### Train with npy file

# %%
#imgs_train,imgs_mask_train = geneTrainNpy("data/membrane/train/aug/","data/membrane/train/aug/")
#model.fit(imgs_train, imgs_mask_train, batch_size=2, nb_epoch=10, verbose=1,validation_split=0.2, shuffle=True, callbacks=[model_checkpoint])

# %% [markdown]
# ### test your model and save predicted results

# %%
testGene = testGenerator("data/membrane/test")
model = unet()
model.load_weights("unet_membrane.hdf5")
results = model.predict_generator(testGene,30,verbose=1)
saveResult("data/membrane/test",results)
# Out:
# Model: "model_1"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_2 (InputLayer)           [(None, 128, 128, 3  0           []
#                                 )]
#
#  conv2d_11 (Conv2D)             (None, 128, 128, 16  448         ['input_2[0][0]']
#                                 )
#
#  dropout_5 (Dropout)            (None, 128, 128, 16  0           ['conv2d_11[0][0]']
#                                 )
#
#  conv2d_12 (Conv2D)             (None, 128, 128, 16  2320        ['dropout_5[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 128, 128, 16  64         ['conv2d_12[0][0]']
#  rmalization)                   )
#
#  re_lu_9 (ReLU)                 (None, 128, 128, 16  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  max_pooling2d_4 (MaxPooling2D)  (None, 64, 64, 16)  0           ['re_lu_9[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 64, 64, 32)   4640        ['max_pooling2d_4[0][0]']
#
#  dropout_6 (Dropout)            (None, 64, 64, 32)   0           ['conv2d_13[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 64, 64, 32)   9248        ['dropout_6[0][0]']
#
#  batch_normalization_10 (BatchN  (None, 64, 64, 32)  128         ['conv2d_14[0][0]']
#  ormalization)
#
#  re_lu_10 (ReLU)                (None, 64, 64, 32)   0           ['batch_normalization_10[0][0]']
#
#  max_pooling2d_5 (MaxPooling2D)  (None, 32, 32, 32)  0           ['re_lu_10[0][0]']
#
#  conv2d_15 (Conv2D)             (None, 32, 32, 64)   18496       ['max_pooling2d_5[0][0]']
#
#  dropout_7 (Dropout)            (None, 32, 32, 64)   0           ['conv2d_15[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 32, 32, 64)   36928       ['dropout_7[0][0]']
#
#  batch_normalization_11 (BatchN  (None, 32, 32, 64)  256         ['conv2d_16[0][0]']
#  ormalization)
#
#  re_lu_11 (ReLU)                (None, 32, 32, 64)   0           ['batch_normalization_11[0][0]']
#
#  max_pooling2d_6 (MaxPooling2D)  (None, 16, 16, 64)  0           ['re_lu_11[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 16, 16, 128)  73856       ['max_pooling2d_6[0][0]']
#
#  dropout_8 (Dropout)            (None, 16, 16, 128)  0           ['conv2d_17[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 16, 16, 128)  147584      ['dropout_8[0][0]']
#
#  batch_normalization_12 (BatchN  (None, 16, 16, 128)  512        ['conv2d_18[0][0]']
#  ormalization)
#
#  re_lu_12 (ReLU)                (None, 16, 16, 128)  0           ['batch_normalization_12[0][0]']
#
#  max_pooling2d_7 (MaxPooling2D)  (None, 8, 8, 128)   0           ['re_lu_12[0][0]']
#
#  conv2d_19 (Conv2D)             (None, 8, 8, 256)    295168      ['max_pooling2d_7[0][0]']
#
#  batch_normalization_13 (BatchN  (None, 8, 8, 256)   1024        ['conv2d_19[0][0]']
#  ormalization)
#
#  re_lu_13 (ReLU)                (None, 8, 8, 256)    0           ['batch_normalization_13[0][0]']
#
#  dropout_9 (Dropout)            (None, 8, 8, 256)    0           ['re_lu_13[0][0]']
#
#  conv2d_20 (Conv2D)             (None, 8, 8, 256)    590080      ['dropout_9[0][0]']
#
#  conv2d_transpose_4 (Conv2DTran  (None, 16, 16, 128)  131200     ['conv2d_20[0][0]']
#  spose)
#
#  concatenate_4 (Concatenate)    (None, 16, 16, 256)  0           ['conv2d_transpose_4[0][0]',
#                                                                   'conv2d_18[0][0]']
#
#  batch_normalization_14 (BatchN  (None, 16, 16, 256)  1024       ['concatenate_4[0][0]']
#  ormalization)
#
#  re_lu_14 (ReLU)                (None, 16, 16, 256)  0           ['batch_normalization_14[0][0]']
#
#  conv2d_transpose_5 (Conv2DTran  (None, 32, 32, 64)  65600       ['re_lu_14[0][0]']
#  spose)
#
#  concatenate_5 (Concatenate)    (None, 32, 32, 128)  0           ['conv2d_transpose_5[0][0]',
#                                                                   'conv2d_16[0][0]']
#
#  batch_normalization_15 (BatchN  (None, 32, 32, 128)  512        ['concatenate_5[0][0]']
#  ormalization)
#
#  re_lu_15 (ReLU)                (None, 32, 32, 128)  0           ['batch_normalization_15[0][0]']
#
#  conv2d_transpose_6 (Conv2DTran  (None, 64, 64, 32)  16416       ['re_lu_15[0][0]']
#  spose)
#
#  concatenate_6 (Concatenate)    (None, 64, 64, 64)   0           ['conv2d_transpose_6[0][0]',
#                                                                   'conv2d_14[0][0]']
#
#  batch_normalization_16 (BatchN  (None, 64, 64, 64)  256         ['concatenate_6[0][0]']
#  ormalization)
#
#  re_lu_16 (ReLU)                (None, 64, 64, 64)   0           ['batch_normalization_16[0][0]']
#
#  conv2d_transpose_7 (Conv2DTran  (None, 128, 128, 16  4112       ['re_lu_16[0][0]']
#  spose)                         )
#
#  concatenate_7 (Concatenate)    (None, 128, 128, 32  0           ['conv2d_transpose_7[0][0]',
#                                 )                                 'conv2d_12[0][0]']
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 32  128        ['concatenate_7[0][0]']
#  ormalization)                  )
#
#  re_lu_17 (ReLU)                (None, 128, 128, 32  0           ['batch_normalization_17[0][0]']
#                                 )
#
#  conv2d_21 (Conv2D)             (None, 128, 128, 1)  33          ['re_lu_17[0][0]']
#
# ==================================================================================================
# Total params: 1,400,033
# Trainable params: 1,398,081
# Non-trainable params: 1,952
# __________________________________________________________________________________________________
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 3
#       1 testGene = testGenerator("data/membrane/test")
#       2 model = unet()
# ----> 3 model.load_weights("unet_membrane.hdf5")
#       4 results = model.predict_generator(testGene,30,verbose=1)
#       5 saveResult("data/membrane/test",results)
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\keras\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\h5py\_hl\files.py:562, in File.__init__(self, name, mode, driver, libver, userblock_size, swmr, rdcc_nslots, rdcc_nbytes, rdcc_w0, track_order, fs_strategy, fs_persist, fs_threshold, fs_page_size, page_buf_size, min_meta_keep, min_raw_keep, locking, alignment_threshold, alignment_interval, meta_block_size, **kwds)
#     553     fapl = make_fapl(driver, libver, rdcc_nslots, rdcc_nbytes, rdcc_w0,
#     554                      locking, page_buf_size, min_meta_keep, min_raw_keep,
#     555                      alignment_threshold=alignment_threshold,
#     556                      alignment_interval=alignment_interval,
#     557                      meta_block_size=meta_block_size,
#     558                      **kwds)
#     559     fcpl = make_fcpl(track_order=track_order, fs_strategy=fs_strategy,
#     560                      fs_persist=fs_persist, fs_threshold=fs_threshold,
#     561                      fs_page_size=fs_page_size)
# --> 562     fid = make_fid(name, mode, userblock_size, fapl, fcpl, swmr=swmr)
#     564 if isinstance(libver, tuple):
#     565     self._libver = libver
#
# File ~\AppData\Local\Programs\Python\Python310\lib\site-packages\h5py\_hl\files.py:235, in make_fid(name, mode, userblock_size, fapl, fcpl, swmr)
#     233     if swmr and swmr_support:
#     234         flags |= h5f.ACC_SWMR_READ
# --> 235     fid = h5f.open(name, flags, fapl=fapl)
#     236 elif mode == 'r+':
#     237     fid = h5f.open(name, h5f.ACC_RDWR, fapl=fapl)
#
# File h5py\_objects.pyx:54, in h5py._objects.with_phil.wrapper()
#
# File h5py\_objects.pyx:55, in h5py._objects.with_phil.wrapper()
#
# File h5py\h5f.pyx:102, in h5py.h5f.open()
#
# FileNotFoundError: [Errno 2] Unable to synchronously open file (unable to open file: name = 'unet_membrane.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)
